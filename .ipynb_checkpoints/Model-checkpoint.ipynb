# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 300
true_a = 0
true_b = 0
true_c = 0
true_d = 0
true_e = 1
true_f = 0

np.random.seed(1111)
x = np.sort(np.random.rand(N))
y = true_a*x**5 + true_b*x**4 + true_c*x**3 + true_d*x**2 + true_e*x + true_f + 0.1*(np.random.rand(N) - np.random.rand(N))
for i in range(len(y)):
    if y[i] < 0:
        y[i] = 0
    elif y[i] > 1:
        y[i] = 1
yerr = 0.05 * np.random.rand(N)

plt.figure(figsize = (10, 6))
plt.errorbar(x, y, yerr, fmt=".k")
line = true_a*x**5 + true_b*x**4 + true_c*x**3 + true_d*x**2 + true_e*x + true_f
plt.plot(x, line, alpha = 0.5, lw = 3, label = "Ideal fit")
plt.legend()
plt.xlabel('Approval', size = 12)
plt.ylabel('Probability of winning', size = 12)
# Out:
# Text(0, 0.5, 'Probability of winning')

# %%
# Assuming Gaussian error
def log_likelihood(theta, x, y, yerr):
    a, b, c, d, e, f = theta
    model = a*x**5 + b*x**4 + c*x**3 + d*x**2 + e*x + f
    sigma2 = yerr ** 2
    return -0.5 * np.sum((y - model) ** 2 / sigma2 + np.log(sigma2))

def log_prior(theta):
    a, b, c, d, e, f = theta
    if 0. < a < 2. and 0. < b < 2. and 0. < c < 2. and 0. < d < 2. and 0. < e < 2. and 0. < f < 2.:
        return 0.0
    return -np.inf

def log_posterior(theta, x, y, yerr):
    lp = log_prior(theta)
    if not np.isfinite(lp):
        return -np.inf
    return lp + log_likelihood(theta, x, y, yerr)

# %%
import emcee

num_iter = 5000
ndim = 6
nwalkers = 32
initial_pos = np.array((1., 1., 1., 1., 1., 1.)) + 0.01 * np.random.randn(nwalkers, ndim)

sampler = emcee.EnsembleSampler(nwalkers, ndim, log_posterior, args=(x, y, yerr))
sampler.run_mcmc(initial_pos, num_iter, progress=True);
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 5000/5000 [00:06<00:00, 759.07it/s]

# %%
import corner

flat_samples = sampler.get_chain(discard=100, thin=15, flat=True)

labels = ['a', 'b', 'c', 'd', 'e', 'f']
fig = corner.corner(flat_samples, labels=labels, quantiles=[0.16, 0.5, 0.84]);
# Out:
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours

# %%
inds = np.random.randint(len(flat_samples), size=100)
x0 = np.linspace(0, 1, 300)
f, ax = plt.subplots(figsize=(10,6))
for ind in inds:
    sample = flat_samples[ind]
    ax.plot(x0, sample[0]*x**5+sample[1]*x**4+sample[2]*x**3+sample[3]*x**2+sample[4]*x+sample[5], alpha=0.05, color='red')
ax.errorbar(x, y, yerr=yerr, linestyle = 'None',capsize=1, marker ='o', color='black', ms=3)
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.set_xlabel('Approval', size = 12)
ax.set_ylabel('Probability of winning', size = 12)
# Out:
# Text(0, 0.5, 'Probability of winning')
